# %% [markdown]
# ##### Lambda Functions in Python
# Lambda functions are small anonymous functions defined using the **lambda** keyword. They can have any number of arguments but only one expression. They are commonly used for short operations or as arguments to higher-order functions.

# %%
#Syntax
lambda arguments: expression

# %%
def addition(a,b):
    return a+b

# %%
addition(2,3)
# Out:
# 5

# %%
addition=lambda a,b:a+b
print(type(addition))
print(addition(5,6))
# Out:
# <class 'function'>
# 11

# %%
def even(num):
    if num%2==0:
        return True
    
even(24)
# Out:
# True

# %%
even1=lambda num:num%2==0
even1(12)
# Out:
# True

# %%
def addition(x,y,z):
    return x+y+z

addition(12,13,14)
# Out:
# 39

# %%
addition1=lambda x,y,z:x+y+z
addition1(12,13,14)
# Out:
# 39

# %%
## map()- applies a function to all items in a list
numbers=[1,2,3,4,5,6]
def square(number):
    return number**2

square(2)
# Out:
# 4

# %%
(list(map(lambda x:x**2,numbers)))
(list(map(square,numbers)))
# Out:
# [1, 4, 9, 16, 25, 36]

# %% [markdown]
# ## `map()` with `lambda`
#
# Uses a **lambda function** with `map()` to apply an operation to every element.
#
# ### Syntax
#
# ```python
# list(map(lambda arguments: expression, iterable))
# ```
#
# ### Example
#
# ```python
# list(map(lambda x: x**2, numbers))
# ```
#
# - `lambda x: x**2` → Squares each number.
# - `map()` → Applies the lambda to every element.
# - `list()` → Converts the map object into a list.
#
# Output
#
# ```python
# [1, 4, 9, 16, 25, 36]
# ```

# %% [markdown]
# ## Lambda Function
#
# A **lambda function** is a small **anonymous (unnamed)** function written in a single line.
#
# ### Syntax
#
# ```python
# lambda arguments: expression
# ```
#
# - `lambda` → Keyword to create a lambda function.
# - `arguments` → Input parameters.
# - `expression` → Single expression whose result is automatically returned.
#
# ### Example
#
# ```python
# square = lambda x: x**2
#
# print(square(5))
# ```
#
# Output
#
# ```python
# 25
# ```
#
# > **Remember:** Lambda functions can contain **only one expression** and automatically return its result.
