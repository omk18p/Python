# %%
age=2
if age>=18:
  print("Allow access")
else:
  print("Deny access")

# %%
age=19

if age>18:
  print("Allow access")
elif age<18:
  print("Deny access")
else:
  print("you are 18")

# %%
for i in range(1,5):
  print(i)
# Out:
# 1
# 2
# 3
# 4

# %%
square=[num**2 for num in range(10)]
print(square)
# Out:
# [0, 1, 4, 9, 16, 25, 36, 49, 64, 81]

# %%
even=[num for num in range(10) if num%2==0]
print(even)
# Out:
# [0, 2, 4, 6, 8]
