# %%
age=2
if age>=18:
  print("Allow access")
else:
  print("Deny access")
# Out:
# Deny access

# %%
age=19

if age>18:
  print("Allow access")
elif age<18:
  print("Deny access")
else:
  print("you are 18")
# Out:
# Allow access

# %%
for i in range(1,5):
  print(i)
# Out:
# 1
# 2
# 3
# 4
